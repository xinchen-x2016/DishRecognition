# %% [markdown]
# ## Imports

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '0'

# %%
import os
from PIL import Image
import numpy as np
import torch
import torch.nn as nn
from torch import optim
from torchvision import models,transforms,datasets
import pandas as pd
from torch.autograd import Variable
import bcolz

# %%
# use_gpu = False
use_gpu = torch.cuda.is_available()
def gpu(x,use_gpu=use_gpu):
    if use_gpu:
        return x.cuda()
    else:
        return x

# %% [markdown]
# ## Data Processing

# %%
data_dir = './Dataset'

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

vgg_format = transforms.Compose([
                transforms.CenterCrop(224),
                transforms.ToTensor(),
                normalize,
            ])

class ImageFolderWithPaths(datasets.ImageFolder):
    """Custom dataset that includes image file paths. Extends
    torchvision.datasets.ImageFolder
    """
    # override the __getitem__ method. this is the method dataloader calls
    def __getitem__(self, index):
        # this is what ImageFolder normally returns 
        original_tuple = super(ImageFolderWithPaths, self).__getitem__(index)
        # the image file path
        path = self.imgs[index][0]
        # make a new tuple that includes original and the path
        tuple_with_path = (original_tuple + (path,))
        return tuple_with_path

dsets = {x: ImageFolderWithPaths(os.path.join(data_dir, x), vgg_format)
         for x in ['train', 'val', 'test']}

    
dset_sizes = {x: len(dsets[x]) for x in ['train', 'val','test']}
dset_classes = dsets['train'].classes
dset_loaders = {x: torch.utils.data.DataLoader(dsets[x], batch_size=64,
                                               shuffle=True, num_workers=6)
                for x in ['train', 'val', 'test']}

# %%
c = 0
for inputs, labels, paths in dset_loaders['train']:
    # use the above variables freely
    print(inputs, labels, paths)
    c += 1
    if c == 1:
        break
# Out:
# tensor([[[[ 1.2557,  1.2899,  1.3755,  ...,  1.3242,  1.2214,  1.1529],
#           [ 1.2557,  1.3070,  1.3755,  ...,  1.3413,  1.2385,  1.1700],
#           [ 1.2214,  1.2728,  1.3242,  ...,  1.3584,  1.2728,  1.1872],
#           ...,
#           [ 0.3481,  0.3652,  0.3652,  ..., -1.3473, -1.3815, -1.3987],
#           [ 0.2624,  0.2967,  0.3309,  ..., -1.3473, -1.3644, -1.3815],
#           [ 0.1597,  0.2111,  0.2967,  ..., -1.3473, -1.3473, -1.3644]],
#
#          [[ 0.9755,  1.0105,  1.0980,  ...,  1.5357,  1.4307,  1.3606],
#           [ 0.9755,  1.0280,  1.0980,  ...,  1.5532,  1.4482,  1.3782],
#           [ 0.9405,  0.9930,  1.0455,  ...,  1.5707,  1.4832,  1.3957],
#           ...,
#           [ 0.0126,  0.0301,  0.0476,  ..., -1.7556, -1.7731, -1.7906],
#           [-0.0399, -0.0049,  0.0301,  ..., -1.7381, -1.7556, -1.7731],
#           [-0.1099, -0.0574,  0.0301,  ..., -1.7381, -1.7381, -1.7556]],
#
#          [[ 0.4788,  0.5136,  0.6008,  ...,  1.9080,  1.8034,  1.7337],
#           [ 0.4788,  0.5311,  0.6008,  ...,  1.9254,  1.8208,  1.7511],
#           [ 0.4439,  0.4962,  0.5485,  ...,  1.9428,  1.8557,  1.7685],
#           ...,
#           [-0.2881, -0.2707, -0.3055,  ..., -1.6302, -1.6127, -1.6302],
#           [-0.3404, -0.3055, -0.2881,  ..., -1.5779, -1.5953, -1.6127],
#           [-0.4275, -0.3753, -0.3055,  ..., -1.5779, -1.5779, -1.5779]]],
#
#
#         [[[ 1.0331,  1.3242,  1.3755,  ...,  0.7933,  0.8276,  0.8618],
#           [ 1.7180,  1.6667,  1.5468,  ...,  0.9474,  0.8961,  0.8961],
#           [ 1.8379,  2.0092,  2.1462,  ...,  1.1529,  0.9988,  0.9474],
#           ...,
#           [-1.3473, -1.5014, -1.6555,  ...,  0.9132,  1.5810,  0.6392],
#           [-1.3644, -1.5357, -1.6898,  ...,  1.4954,  0.7077,  1.4440],
#           [-1.3987, -1.5699, -1.7240,  ...,  1.9578,  0.6563,  0.9132]],
#
#          [[ 0.3277,  0.6254,  0.6779,  ...,  0.9930,  1.0280,  1.0630],
#           [ 1.1155,  1.0630,  0.9055,  ...,  1.1506,  1.0980,  1.0980],
#           [ 1.3606,  1.5532,  1.6758,  ...,  1.3606,  1.2381,  1.1856],
#           ...,
#           [-1.5455, -1.7031, -1.8081,  ...,  0.6429,  1.2906,  0.3452],
#           [-1.5630, -1.7381, -1.8431,  ...,  1.2556,  0.4328,  1.2031],
#           [-1.5980, -1.7731, -1.8782,  ...,  1.7283,  0.3803,  0.6604]],
#
#          [[-1.2816, -0.9330, -0.7587,  ...,  1.9254,  1.9951,  2.0300],
#           [-0.3927, -0.3753, -0.4101,  ...,  2.0823,  2.0648,  2.0648],
#           [ 0.0431,  0.3045,  0.5311,  ...,  2.2914,  2.1520,  2.1346],
#           ...,
#           [-1.4907, -1.6476, -1.7347,  ...,  0.2348,  0.8622, -0.1487],
#           [-1.5081, -1.6824, -1.7696,  ...,  0.8797, -0.0092,  0.7054],
#           [-1.5430, -1.7173, -1.8044,  ...,  1.3502, -0.0615,  0.1651]]],
#
#
#         [[[ 1.5468,  1.4783,  1.3927,  ..., -0.1143,  0.2282,  0.5193],
#           [ 1.5639,  1.5125,  1.4269,  ..., -0.2342, -0.0287,  0.1426],
#           [ 1.5810,  1.5468,  1.4783,  ..., -0.2684, -0.2171, -0.1657],
#           ...,
#           [ 1.3584,  1.3413,  1.3070,  ...,  1.7523,  1.7523,  1.7523],
#           [ 1.3755,  1.3413,  1.3242,  ...,  1.7523,  1.7694,  1.7694],
#           [ 1.4098,  1.3927,  1.3584,  ...,  1.7694,  1.7694,  1.7865]],
#
#          [[ 1.1681,  1.1155,  1.0805,  ..., -0.8102, -0.4426, -0.1450],
#           [ 1.1856,  1.1506,  1.1155,  ..., -0.9328, -0.7227, -0.5301],
#           [ 1.2206,  1.1856,  1.1506,  ..., -0.9853, -0.9153, -0.8627],
#           ...,
#           [ 1.6758,  1.6583,  1.6232,  ...,  1.9734,  1.9734,  1.9734],
#           [ 1.6933,  1.6583,  1.6408,  ...,  1.9734,  1.9909,  1.9909],
#           [ 1.7283,  1.7108,  1.6758,  ...,  1.9909,  1.9909,  2.0084]],
#
#          [[ 0.8971,  0.8448,  0.8274,  ..., -0.8981, -0.4973, -0.1835],
#           [ 0.9145,  0.8797,  0.8622,  ..., -1.0201, -0.7761, -0.5844],
#           [ 0.9494,  0.9494,  0.9494,  ..., -1.1073, -1.0027, -0.9156],
#           ...,
#           [ 2.0474,  2.0300,  1.9951,  ...,  2.2740,  2.2740,  2.2740],
#           [ 2.0648,  2.0300,  2.0125,  ...,  2.2740,  2.2914,  2.2914],
#           [ 2.0997,  2.0823,  2.0474,  ...,  2.2914,  2.2914,  2.3088]]],
#
#
#         ...,
#
#
#         [[[ 0.8104,  0.8104,  0.8104,  ...,  1.1015,  1.1015,  1.1015],
#           [ 0.8104,  0.8104,  0.8276,  ...,  1.1015,  1.1015,  1.1015],
#           [ 0.8276,  0.8276,  0.8276,  ...,  1.1015,  1.1015,  1.1015],
#           ...,
#           [ 1.2385,  1.2214,  1.2214,  ...,  0.8789,  0.8789,  0.8789],
#           [ 1.2385,  1.2214,  1.2214,  ...,  0.8789,  0.8789,  0.8789],
#           [ 1.2385,  1.2214,  1.2214,  ...,  0.8789,  0.8789,  0.8789]],
#
#          [[ 1.7458,  1.7458,  1.7458,  ...,  2.0434,  2.0434,  2.0434],
#           [ 1.7458,  1.7458,  1.7633,  ...,  2.0434,  2.0434,  2.0434],
#           [ 1.7633,  1.7633,  1.7633,  ...,  2.0434,  2.0434,  2.0434],
#           ...,
#           [ 2.1134,  2.0959,  2.0959,  ...,  1.8333,  1.8333,  1.8333],
#           [ 2.1134,  2.0959,  2.0959,  ...,  1.8333,  1.8333,  1.8333],
#           [ 2.1134,  2.0959,  2.0959,  ...,  1.8333,  1.8333,  1.8333]],
#
#          [[ 2.5006,  2.5006,  2.5006,  ...,  2.6226,  2.6226,  2.6226],
#           [ 2.5006,  2.5006,  2.5180,  ...,  2.6226,  2.6226,  2.6226],
#           [ 2.5180,  2.5180,  2.5180,  ...,  2.6226,  2.6226,  2.6226],
#           ...,
#           [ 2.6400,  2.6400,  2.6400,  ...,  2.5006,  2.5006,  2.5006],
#           [ 2.6400,  2.6400,  2.6400,  ...,  2.5006,  2.5006,  2.5006],
#           [ 2.6400,  2.6400,  2.6400,  ...,  2.5006,  2.5006,  2.5006]]],
#
#
#         [[[ 1.1872,  1.2728,  1.3755,  ...,  2.2147,  2.2147,  2.2147],
#           [ 1.2557,  1.2728,  1.2899,  ...,  2.2147,  2.2147,  2.2147],
#           [ 1.2557,  1.2214,  1.1872,  ...,  2.2147,  2.2147,  2.2147],
#           ...,
#           [-0.0458,  0.0569,  0.1083,  ...,  1.2214,  0.8104,  1.2043],
#           [ 0.0056,  0.0741, -0.0287,  ...,  0.8104,  1.1015,  1.0331],
#           [-0.0116, -0.0458, -0.2171,  ...,  1.1187,  1.0502,  0.8447]],
#
#          [[ 1.5357,  1.6232,  1.7283,  ...,  2.4286,  2.3936,  2.3936],
#           [ 1.6057,  1.6232,  1.6408,  ...,  2.4286,  2.3936,  2.3936],
#           [ 1.5882,  1.5532,  1.5182,  ...,  2.4286,  2.3936,  2.3936],
#           ...,
#           [-0.0049,  0.1001,  0.1527,  ...,  1.6583,  1.2031,  1.6057],
#           [ 0.0476,  0.1176,  0.0126,  ...,  1.2381,  1.5007,  1.4307],
#           [ 0.0301, -0.0049, -0.1800,  ...,  1.5532,  1.4482,  1.2381]],
#
#          [[ 1.7860,  1.8731,  1.9777,  ...,  2.6226,  2.5703,  2.5703],
#           [ 1.8557,  1.8731,  1.8905,  ...,  2.6226,  2.5703,  2.5703],
#           [ 1.8383,  1.8034,  1.7685,  ...,  2.6226,  2.5703,  2.5703],
#           ...,
#           [-0.3055, -0.2010, -0.1487,  ...,  1.8731,  1.4374,  1.8383],
#           [-0.2532, -0.1835, -0.2881,  ...,  1.4548,  1.7337,  1.6640],
#           [-0.2707, -0.3055, -0.4798,  ...,  1.7685,  1.6814,  1.4722]]],
#
#
#         [[[ 1.4783,  1.4783,  1.4612,  ...,  2.1119,  2.1119,  2.1119],
#           [ 1.4440,  1.4440,  1.4269,  ...,  2.1119,  2.1119,  2.1119],
#           [ 1.3755,  1.3927,  1.3927,  ...,  2.1119,  2.1119,  2.1119],
#           ...,
#           [ 0.6049,  0.8618,  0.8447,  ...,  1.9064,  2.0263,  2.0263],
#           [ 0.7077,  0.8276,  0.7419,  ...,  2.0263,  2.0092,  1.9749],
#           [ 0.6221,  0.6734,  0.7591,  ...,  2.0948,  2.0948,  2.1462]],
#
#          [[ 1.6232,  1.6232,  1.6057,  ...,  2.3060,  2.3060,  2.3060],
#           [ 1.5882,  1.5882,  1.5707,  ...,  2.3060,  2.3060,  2.3060],
#           [ 1.5182,  1.5357,  1.5357,  ...,  2.3060,  2.3060,  2.3060],
#           ...,
#           [ 0.7304,  0.9930,  0.9755,  ...,  2.0784,  2.2010,  2.2010],
#           [ 0.8354,  0.9580,  0.8704,  ...,  2.2010,  2.1835,  2.1485],
#           [ 0.7479,  0.8004,  0.8880,  ...,  2.2710,  2.2710,  2.3235]],
#
#          [[ 1.3502,  1.3502,  1.3328,  ...,  2.6051,  2.6051,  2.6051],
#           [ 1.3154,  1.3154,  1.2980,  ...,  2.6051,  2.6051,  2.6051],
#           [ 1.2457,  1.2631,  1.2631,  ...,  2.6051,  2.6051,  2.6051],
#           ...,
#           [ 0.9145,  1.1759,  1.1585,  ...,  2.3263,  2.4483,  2.4483],
#           [ 1.0191,  1.1411,  1.0539,  ...,  2.4483,  2.4308,  2.3960],
#           [ 0.9319,  0.9842,  1.0714,  ...,  2.5180,  2.5180,  2.5703]]]]) tensor([160,  46,  82,  67,  25,  85, 110, 104,  52, 165, 103, 100,  49,   1,
#          66, 132, 137,  98,  17, 140,   8,  70,   1,  21,  77,  66, 105,  82,
#         161, 143, 100, 126,  17,  15, 151,  38, 118,  99, 136, 107, 106, 127,
#           6,  38, 141, 125, 161,  49,  31,  79,  47, 106, 122,  42,   4, 161,
#          47,   3,  74,  25,   1,  99, 139,  32]) ('./Dataset/train/89/1_13.jpg', './Dataset/train/140/3_35.jpg', './Dataset/train/18/8_11.jpg', './Dataset/train/16/1_52.jpg', './Dataset/train/121/11_36.jpg', './Dataset/train/20/3_23.jpg', './Dataset/train/43/20_31.jpg', './Dataset/train/38/3_15.jpg', './Dataset/train/146/Shaomai_by_Kent_Wang_in_Seattle,_Vancouver.jpg', './Dataset/train/93/4_54.jpg', './Dataset/train/37/17_56.jpg', './Dataset/train/34/20_29.jpg', './Dataset/train/143/1_31.jpg', './Dataset/train/10/2_33.jpg', './Dataset/train/159/7_3.jpg', './Dataset/train/63/9_34.jpg', './Dataset/train/68/10_49.jpg', './Dataset/train/32/17_43.jpg', './Dataset/train/114/71ec61a3bef34b15a3ca3b389577101d.jpg', './Dataset/train/70/11_42.jpg', './Dataset/train/106/6_1.jpg', './Dataset/train/162/3_17.jpg', './Dataset/train/10/1-120604151T2C0.jpg', './Dataset/train/118/11_29.jpg', './Dataset/train/169/10_48.jpg', './Dataset/train/159/14_17.jpg', './Dataset/train/39/2_6.jpg', './Dataset/train/18/5_55.jpg', './Dataset/train/9/8_15.jpg', './Dataset/train/73/5_43.jpg', './Dataset/train/34/10873928_103002159161_2.jpg', './Dataset/train/58/12_29.jpg', './Dataset/train/114/13_34.jpg', './Dataset/train/112/14_30.jpg', './Dataset/train/80/2_11.jpg', './Dataset/train/133/12_6.jpg', './Dataset/train/50/7_5.jpg', './Dataset/train/33/6_53.jpg', './Dataset/train/67/18_1.jpg', './Dataset/train/40/17_34.jpg', './Dataset/train/4/3_53.jpg', './Dataset/train/59/20_40.jpg', './Dataset/train/104/7_43.jpg', './Dataset/train/133/16_35.jpg', './Dataset/train/71/19300001351681131425221417162.jpg', './Dataset/train/57/4_8.jpg', './Dataset/train/9/2_44.jpg', './Dataset/train/143/2_50.jpg', './Dataset/train/127/9885883_115948767000_2.jpg', './Dataset/train/170/xiachufang_68.jpg', './Dataset/train/141/3_28.jpg', './Dataset/train/4/8_23.jpg', './Dataset/train/54/2_38.jpg', './Dataset/train/137/1_24.jpg', './Dataset/train/102/2_17.jpg', './Dataset/train/9/11_7.jpg', './Dataset/train/141/15_27.jpg', './Dataset/train/101/3_47.jpg', './Dataset/train/166/10_37.jpg', './Dataset/train/121/19_38.jpg', './Dataset/train/10/2_37.jpg', './Dataset/train/33/2_56.jpg', './Dataset/train/7/1_11.jpg', './Dataset/train/128/15_0.jpg')

# %%
# clean IngredientList.txt and output the doublets
ing_list = './IngredientList.txt'
text_file = open("./IngredientList.txt", "r")
lines = text_file.read().split('\n')
ing_dict = {}
i = 0
for l in lines:
    ing_dict[i] = l
    i += 1
for key, val in ing_dict.items():
    val = val.lower()
    if "\ufeff" in val:
        val = val.replace('\ufeff','')
    if "of" in val:
        val = val.replace('of ','')
    if "chiffonade" in val:
        val = val.replace('chiffonade','sliced')
    if "slices" in val:
        val = val.replace('slices','sliced')
    if 'julienned' in val:
        val = val.replace('julienned', 'shredded')
    val = val.replace(' ', '')
    ing_dict[key] = val

cut_set = {0: "batonnet", 1: "minced", 2: "sliced", 3: "crushed", 4: "shredded", 5: "brunoisediced", 6: "chopped", 7:"chunks", 8: "fried", 9: "steamed", 10: "boiled", 11: "pickled", 12: "seared", 13: "dried"}

new_ing_dict = {}
ing_set = {}
i, j = 0, 0

for idx, val in ing_dict.items():
    new_ing_dict[idx] = [0,-1]
    for jdx, cut in cut_set.items():
        if cut in val:
            new_ing_dict[idx][0] = jdx+1
            val = val.replace(cut, '')
    if not val in ing_set.values():
        ing_set[j] = val
        j += 1
        new_ing_dict[idx][1] = j
    else:
        new_ing_dict[idx][1] = list(ing_set.keys())[list(ing_set.values()).index(val)]

# %%
ing_set
# Out:
# {0: 'greenonion',
#  1: 'whiteonion',
#  2: 'ham',
#  3: 'carrot',
#  4: 'hobblockscarrot',
#  5: 'blacksesame',
#  6: 'whitesesame',
#  7: 'pepper',
#  8: 'wholegreenpepper',
#  9: 'chineseparsleycoriander',
#  10: 'beansprouts',
#  11: 'bacon',
#  12: 'tomatosclices',
#  13: 'cherrytomato',
#  14: 'greenvegetables',
#  15: 'cornkernels',
#  16: 'cornblocks',
#  17: 'bittergourd',
#  18: 'broccoli',
#  19: 'cauliflower',
#  20: 'toast',
#  21: 'bread',
#  22: 'chinesemahogany',
#  23: 'crabsticks',
#  24: 'bambooshootstips',
#  25: 'chivepieces',
#  26: 'chives',
#  27: 'onion',
#  28: 'pumpkinblocks',
#  29: 'groundnutkernels',
#  30: 'lemon',
#  31: 'shelledfreshshrimps',
#  32: 'seashrimp',
#  33: 'freshshrimp',
#  34: 'crayfish',
#  35: 'cucumber',
#  36: 'hobblockscucumber',
#  37: 'hotanddrychili',
#  38: 'hotanddrypepper',
#  39: 'hotanddrypepperpowder',
#  40: 'purplecabbage',
#  41: 'chinesecabbage',
#  42: 'blackfungus',
#  43: 'perillacrispatanaka',
#  44: 'ginger',
#  45: 'scrambledegg',
#  46: 'eggcake',
#  47: 'eggcrepe',
#  48: 'spicedcornedegg',
#  49: 'eggyolk',
#  50: 'eggcustard',
#  51: 'boildegg',
#  52: 'boildeggs',
#  53: 'eggdrop',
#  54: 'quaileggs',
#  55: 'pork',
#  56: 'wolfberry',
#  57: 'streakypork',
#  58: 'curedmeat',
#  59: 'kaleborecole',
#  60: 'porkintestines',
#  61: 'lettuce',
#  62: 'reddates',
#  63: 'kiwi',
#  64: 'garlicclove',
#  65: 'garlic',
#  66: 'garlicbulb',
#  67: 'lentinusedodes',
#  68: 'pleurotusostreatus',
#  69: 'poplarmushroom',
#  70: 'mushroom',
#  71: 'whitebeechmushroom',
#  72: 'yam',
#  73: 'whiteyam',
#  74: 'strawberry',
#  75: 'seacucumber',
#  76: 'shanghaicabbage',
#  77: 'asparagus',
#  78: 'bambooshoots',
#  79: 'rice',
#  80: 'meatballs',
#  81: 'beafballs',
#  82: 'shrimpballs',
#  83: 'fishballs',
#  84: 'blueberryjam',
#  85: 'orange',
#  86: 'mango',
#  87: 'noodles',
#  88: 'beef',
#  89: 'fattybeef',
#  90: 'tofu',
#  91: 'chibabeancurd',
#  92: 'fishbeancurd',
#  93: 'stinkytofu',
#  94: 'beancurd',
#  95: 'hobblockspotato',
#  96: 'potato',
#  97: 'mashedpotatoes',
#  98: 'chilioil',
#  99: 'chilisaurce',
#  100: 'chilipowder',
#  101: 'garlicsproutpieces',
#  102: 'garlicsprout',
#  103: 'garlicleaves',
#  104: 'redpeppers',
#  105: 'capsicumannumfasciculatum',
#  106: 'kelp',
#  107: 'bullfrog',
#  108: 'caviar',
#  109: 'lotusroot',
#  110: 'lotusrootbox',
#  111: 'celtucesclices',
#  112: 'celtuce',
#  113: 'sweetpotato',
#  114: 'sausage',
#  115: 'cabbage',
#  116: 'spareribs',
#  117: 'clams',
#  118: 'liliumbrownii',
#  119: 'fermentedvegetables',
#  120: 'double-sideegg',
#  121: 'radish',
#  122: 'hobblocksradish',
#  123: 'mashedradish',
#  124: 'flatbread',
#  125: 'springrolls',
#  126: 'chicken',
#  127: 'tentaclessquid',
#  128: 'squidpieces',
#  129: 'squidrings',
#  130: 'whitegourd',
#  131: 'piecesbeancurd',
#  132: 'yellowpeaches',
#  133: 'pineapple',
#  134: 'eggplant',
#  135: 'eggplantslice',
#  136: 'hobblockseggplant',
#  137: 'eggplantsticks',
#  138: 'watermellon',
#  139: 'gluten',
#  140: 'dumplings',
#  141: 'breadstick',
#  142: 'hotmustard',
#  143: 'sesamesauce',
#  144: 'soya-beansprout',
#  145: 'beeftripe',
#  146: 'waterspinach',
#  147: 'barbecuedpork',
#  148: 'chickenfeet',
#  149: 'coldricenoodles',
#  150: 'mutton',
#  151: 'smallloafbread',
#  152: 'starchsheet',
#  153: 'yuba',
#  154: 'okra',
#  155: 'chestnut',
#  156: 'preservedegg',
#  157: 'wholepreservedegg',
#  158: 'laver',
#  159: 'doughtwist',
#  160: 'longan',
#  161: 'stewedpork',
#  162: 'beans',
#  163: 'sweetfermentedflourpaste',
#  164: 'riversnail',
#  165: 'spinach',
#  166: 'seasedge',
#  167: 'bracken',
#  168: 'coprinuscomatus',
#  169: 'limeleaves',
#  170: 'lemongrass',
#  171: 'lime',
#  172: 'chickenwings',
#  173: 'snowpeas',
#  174: 'vegetable',
#  175: 'saltedegg',
#  176: 'curry',
#  177: 'blackpepperpowder',
#  178: 'flour',
#  179: 'wholeblackchicken',
#  180: 'blackchicken',
#  181: 'celerystalk',
#  182: 'celeryleaves',
#  183: 'celery',
#  184: 'banana',
#  185: 'apple',
#  186: 'loofah',
#  187: 'fish',
#  188: 'zucchini',
#  189: 'wholechicken',
#  190: 'tenderloin',
#  191: 'whitecongee',
#  192: 'spaghetti',
#  193: 'steak',
#  194: 'cuminpowder',
#  195: 'beeftripes',
#  196: 'pinenuts',
#  197: 'gemelli',
#  198: 'koreanchilisauce',
#  199: 'kidneybean',
#  200: 'zanthoxylumfagara',
#  201: 'ricenoodle',
#  202: 'yubaskin',
#  203: 'saladdressing',
#  204: 'soyabean',
#  205: 'fernrootnoodles',
#  206: 'ketchup',
#  207: 'mintleaf',
#  208: 'soysauce',
#  209: 'babychinesecabbage',
#  210: 'water',
#  211: 'lotusseeds',
#  212: 'azukibean',
#  213: 'greensoybean',
#  214: 'parsley',
#  215: 'duckneck',
#  216: 'thickbroad-beansauce',
#  217: 'enokimushroom',
#  218: 'crystalsugar',
#  219: 'cashew',
#  220: 'bun',
#  221: 'soursauce',
#  222: 'porkleg',
#  223: 'bayleaf',
#  224: 'shumai',
#  225: 'craproe',
#  226: 'shrimpeggs',
#  227: 'buttonmushroom',
#  228: 'coconutwater',
#  229: 'glutinousrice',
#  230: 'sweetpotatostarchnoodles',
#  231: 'vermicelli',
#  232: 'fermentedsoyabeans',
#  233: 'ricedumpling',
#  234: 'sweetenedbeanpaste',
#  235: 'sweetdumplings',
#  236: 'ricenoodleroll',
#  237: 'pea',
#  238: 'porkfloss',
#  239: 'scallionpancake',
#  240: 'blackrice',
#  241: 'smallcrispyrice',
#  242: 'coconutcake',
#  243: 'coconutstuffing',
#  244: 'mussels',
#  245: 'porklungs',
#  246: 'crispysausage',
#  247: 'codonopsispilosula',
#  248: 'radixastragali',
#  249: 'americangenseng',
#  250: 'cordycepssinensis',
#  251: 'aniseed',
#  252: 'raisin',
#  253: 'sucklingpig',
#  254: 'twistedroll',
#  255: 'grape',
#  256: 'porkpaste',
#  257: 'cheese',
#  258: 'wonton',
#  259: 'duckhead',
#  260: 'chinesekale',
#  261: 'chickenlegs',
#  262: 'sweetandsoursauce',
#  263: 'fishhead',
#  264: 'ricepowder',
#  265: 'scallop',
#  266: 'macaroni',
#  267: 'ribbonfish',
#  268: 'tea-leaves',
#  269: 'millet',
#  270: 'preservedvegetables',
#  271: 'coixseed',
#  272: 'greenbeans',
#  273: 'whitefungus',
#  274: 'crucian',
#  275: 'vinegar',
#  276: 'pancakes',
#  277: 'crispbread',
#  278: 'crab',
#  279: 'soya-beanmilk',
#  280: 'fermentedsoybeanpaste',
#  281: 'oystersauce',
#  282: 'greensoybeans',
#  283: 'cherry',
#  284: 'pigears',
#  285: ''}

# %%
new_ing_dict
# Out:
# {0: [2, 1],
#  1: [3, 0],
#  2: [13, 0],
#  3: [0, 2],
#  4: [6, 3],
#  5: [5, 2],
#  6: [0, 2],
#  7: [3, 2],
#  8: [6, 4],
#  9: [3, 3],
#  10: [1, 3],
#  11: [5, 3],
#  12: [0, 5],
#  13: [0, 6],
#  14: [0, 7],
#  15: [4, 8],
#  16: [5, 7],
#  17: [3, 7],
#  18: [13, 7],
#  19: [0, 7],
#  20: [0, 9],
#  21: [0, 10],
#  22: [0, 11],
#  23: [0, 12],
#  24: [0, 13],
#  25: [3, 14],
#  26: [0, 13],
#  27: [0, 15],
#  28: [3, 14],
#  29: [0, 16],
#  30: [0, 17],
#  31: [3, 18],
#  32: [0, 19],
#  33: [0, 20],
#  34: [0, 21],
#  35: [0, 22],
#  36: [0, 23],
#  37: [0, 24],
#  38: [0, 25],
#  39: [0, 26],
#  40: [7, 27],
#  41: [0, 26],
#  42: [5, 28],
#  43: [3, 27],
#  44: [6, 27],
#  45: [0, 29],
#  46: [0, 30],
#  47: [4, 29],
#  48: [0, 31],
#  49: [0, 32],
#  50: [14, 33],
#  51: [0, 34],
#  52: [0, 35],
#  53: [5, 36],
#  54: [1, 35],
#  55: [0, 37],
#  56: [3, 35],
#  57: [6, 35],
#  58: [4, 38],
#  59: [0, 39],
#  60: [0, 40],
#  61: [3, 41],
#  62: [0, 42],
#  63: [0, 43],
#  64: [0, 44],
#  65: [3, 45],
#  66: [5, 44],
#  67: [7, 44],
#  68: [0, 46],
#  69: [0, 47],
#  70: [4, 48],
#  71: [0, 49],
#  72: [0, 50],
#  73: [10, 51],
#  74: [3, 52],
#  75: [0, 53],
#  76: [0, 54],
#  77: [5, 47],
#  78: [0, 55],
#  79: [2, 56],
#  80: [0, 57],
#  81: [2, 55],
#  82: [5, 55],
#  83: [3, 58],
#  84: [3, 55],
#  85: [8, 55],
#  86: [8, 57],
#  87: [8, 59],
#  88: [0, 60],
#  89: [0, 61],
#  90: [0, 62],
#  91: [10, 21],
#  92: [0, 63],
#  93: [0, 64],
#  94: [0, 65],
#  95: [4, 66],
#  96: [0, 67],
#  97: [0, 68],
#  98: [3, 67],
#  99: [6, 67],
#  100: [0, 69],
#  101: [0, 70],
#  102: [14, 71],
#  103: [0, 72],
#  104: [8, 73],
#  105: [0, 74],
#  106: [3, 72],
#  107: [0, 75],
#  108: [0, 76],
#  109: [0, 77],
#  110: [0, 78],
#  111: [8, 79],
#  112: [5, 78],
#  113: [0, 80],
#  114: [0, 81],
#  115: [0, 82],
#  116: [0, 83],
#  117: [0, 84],
#  118: [0, 85],
#  119: [3, 86],
#  120: [0, 87],
#  121: [0, 88],
#  122: [8, 89],
#  123: [3, 88],
#  124: [3, 90],
#  125: [8, 91],
#  126: [0, 92],
#  127: [0, 93],
#  128: [0, 94],
#  129: [14, 95],
#  130: [0, 96],
#  131: [3, 97],
#  132: [5, 96],
#  133: [0, 98],
#  134: [1, 96],
#  135: [0, 99],
#  136: [0, 100],
#  137: [0, 101],
#  138: [0, 102],
#  139: [6, 103],
#  140: [0, 104],
#  141: [12, 105],
#  142: [12, 106],
#  143: [12, 105],
#  144: [5, 107],
#  145: [0, 106],
#  146: [0, 108],
#  147: [0, 109],
#  148: [3, 110],
#  149: [8, 109],
#  150: [0, 111],
#  151: [0, 112],
#  152: [1, 113],
#  153: [5, 112],
#  154: [8, 114],
#  155: [3, 115],
#  156: [0, 116],
#  157: [3, 115],
#  158: [0, 117],
#  159: [0, 118],
#  160: [0, 119],
#  161: [0, 120],
#  162: [9, 121],
#  163: [9, 120],
#  164: [3, 122],
#  165: [1, 121],
#  166: [0, 123],
#  167: [5, 121],
#  168: [12, 124],
#  169: [12, 121],
#  170: [0, 125],
#  171: [0, 126],
#  172: [8, 127],
#  173: [6, 126],
#  174: [0, 128],
#  175: [0, 129],
#  176: [0, 130],
#  177: [8, 131],
#  178: [14, 132],
#  179: [0, 133],
#  180: [0, 134],
#  181: [0, 135],
#  182: [0, 136],
#  183: [1, 134],
#  184: [0, 137],
#  185: [0, 138],
#  186: [0, 139],
#  187: [0, 140],
#  188: [8, 139],
#  189: [0, 141],
#  190: [9, 142],
#  191: [9, 141],
#  192: [12, 143],
#  193: [0, 144],
#  194: [0, 145],
#  195: [5, 146],
#  196: [0, 147],
#  197: [12, 78],
#  198: [3, 148],
#  199: [8, 147],
#  200: [0, 149],
#  201: [10, 150],
#  202: [3, 151],
#  203: [8, 150],
#  204: [10, 152],
#  205: [10, 151],
#  206: [0, 153],
#  207: [0, 154],
#  208: [3, 155],
#  209: [0, 156],
#  210: [8, 157],
#  211: [4, 156],
#  212: [0, 158],
#  213: [0, 159],
#  214: [9, 160],
#  215: [0, 161],
#  216: [0, 162],
#  217: [0, 163],
#  218: [2, 162],
#  219: [12, 162],
#  220: [0, 164],
#  221: [0, 165],
#  222: [0, 166],
#  223: [0, 167],
#  224: [0, 168],
#  225: [0, 169],
#  226: [0, 170],
#  227: [0, 171],
#  228: [0, 172],
#  229: [0, 173],
#  230: [0, 174],
#  231: [12, 175],
#  232: [0, 176],
#  233: [0, 177],
#  234: [0, 178],
#  235: [9, 179],
#  236: [0, 180],
#  237: [8, 181],
#  238: [3, 182],
#  239: [0, 181],
#  240: [0, 183],
#  241: [0, 184],
#  242: [6, 183],
#  243: [3, 185],
#  244: [8, 186],
#  245: [0, 187],
#  246: [3, 188],
#  247: [8, 187],
#  248: [0, 187],
#  249: [3, 189],
#  250: [11, 126],
#  251: [11, 190],
#  252: [3, 191],
#  253: [8, 190],
#  254: [1, 190],
#  255: [0, 192],
#  256: [0, 193],
#  257: [0, 194],
#  258: [0, 195],
#  259: [0, 196],
#  260: [0, 197],
#  261: [0, 198],
#  262: [0, 199],
#  263: [0, 200],
#  264: [0, 201],
#  265: [0, 202],
#  266: [9, 203],
#  267: [0, 204],
#  268: [0, 205],
#  269: [0, 206],
#  270: [0, 207],
#  271: [0, 208],
#  272: [0, 209],
#  273: [0, 210],
#  274: [0, 211],
#  275: [0, 212],
#  276: [0, 213],
#  277: [0, 214],
#  278: [0, 215],
#  279: [0, 216],
#  280: [0, 217],
#  281: [0, 218],
#  282: [0, 219],
#  283: [0, 220],
#  284: [10, 221],
#  285: [0, 222],
#  286: [0, 223],
#  287: [0, 224],
#  288: [0, 225],
#  289: [0, 226],
#  290: [0, 227],
#  291: [0, 228],
#  292: [0, 229],
#  293: [0, 230],
#  294: [0, 231],
#  295: [0, 232],
#  296: [0, 233],
#  297: [0, 234],
#  298: [0, 235],
#  299: [0, 236],
#  300: [0, 237],
#  301: [0, 238],
#  302: [0, 239],
#  303: [0, 240],
#  304: [0, 241],
#  305: [0, 242],
#  306: [0, 243],
#  307: [5, 244],
#  308: [0, 245],
#  309: [0, 246],
#  310: [0, 247],
#  311: [0, 248],
#  312: [0, 249],
#  313: [0, 250],
#  314: [0, 251],
#  315: [0, 252],
#  316: [0, 253],
#  317: [0, 254],
#  318: [10, 255],
#  319: [0, 256],
#  320: [0, 257],
#  321: [0, 258],
#  322: [0, 259],
#  323: [0, 260],
#  324: [0, 261],
#  325: [0, 262],
#  326: [0, 189],
#  327: [5, 126],
#  328: [0, 263],
#  329: [0, 264],
#  330: [10, 265],
#  331: [0, 266],
#  332: [0, 267],
#  333: [0, 268],
#  334: [0, 269],
#  335: [0, 270],
#  336: [0, 271],
#  337: [0, 272],
#  338: [0, 273],
#  339: [0, 274],
#  340: [0, 275],
#  341: [0, 276],
#  342: [0, 277],
#  343: [0, 278],
#  344: [8, 86],
#  345: [0, 279],
#  346: [0, 280],
#  347: [0, 281],
#  348: [0, 282],
#  349: [8, 116],
#  350: [0, 283],
#  351: [0, 284],
#  352: [5, 285],
#  353: [0, 286]}

# %%
ing_dict
# Out:
# {0: 'mincedgreenonion',
#  1: 'slicedgreenonion',
#  2: 'searedgreenonion',
#  3: 'whiteonion',
#  4: 'brunoisedicedham',
#  5: 'shreddedham',
#  6: 'ham',
#  7: 'slicedham',
#  8: 'brunoisedicedcarrot',
#  9: 'slicedcarrot',
#  10: 'batonnetcarrot',
#  11: 'shreddedcarrot',
#  12: 'hobblockscarrot',
#  13: 'blacksesame',
#  14: 'whitesesame',
#  15: 'crushedpepper',
#  16: 'shreddedpepper',
#  17: 'peppersliced',
#  18: 'searedpepper',
#  19: 'pepper',
#  20: 'wholegreenpepper',
#  21: 'chineseparsleycoriander',
#  22: 'beansprouts',
#  23: 'bacon',
#  24: 'tomatosclices',
#  25: 'cherrytomatosliced',
#  26: 'cherrytomato',
#  27: 'greenvegetables',
#  28: 'slicedgreenvegetables',
#  29: 'cornkernels',
#  30: 'cornblocks',
#  31: 'bittergourdsliced',
#  32: 'broccoli',
#  33: 'cauliflower',
#  34: 'toast',
#  35: 'bread',
#  36: 'chinesemahogany',
#  37: 'crabsticks',
#  38: 'bambooshootstips',
#  39: 'chivepieces',
#  40: 'choppedchives',
#  41: 'chives',
#  42: 'shreddedonion',
#  43: 'onionsliced',
#  44: 'brunoisedicedonion',
#  45: 'pumpkinblocks',
#  46: 'groundnutkernels',
#  47: 'crushedgroundnutkernels',
#  48: 'lemon',
#  49: 'shelledfreshshrimps',
#  50: 'driedseashrimp',
#  51: 'freshshrimp',
#  52: 'crayfish',
#  53: 'shreddedcucumber',
#  54: 'batonnetcucumber',
#  55: 'hobblockscucumber',
#  56: 'cucumbersliced',
#  57: 'brunoisedicedcucumber',
#  58: 'crushedhotanddrychili',
#  59: 'hotanddrypepper',
#  60: 'hotanddrypepperpowder',
#  61: 'slicedpurplecabbage',
#  62: 'chinesecabbage',
#  63: 'blackfungus',
#  64: 'perillacrispatanaka',
#  65: 'gingersliced',
#  66: 'shreddedginger',
#  67: 'choppedginger',
#  68: 'scrambledegg',
#  69: 'eggcake',
#  70: 'crushedeggcrepe',
#  71: 'spicedcornedegg',
#  72: 'eggyolk',
#  73: 'steamedeggcustard',
#  74: 'boildeggsliced',
#  75: 'boildeggs',
#  76: 'eggdrop',
#  77: 'shreddedeggcrepe',
#  78: 'quaileggs',
#  79: 'mincedpork',
#  80: 'wolfberry',
#  81: 'mincedpork',
#  82: 'shreddedpork',
#  83: 'streakyporksliced',
#  84: 'porksliced',
#  85: 'porkchunks',
#  86: 'streakyporkchunks',
#  87: 'curedmeatchunks',
#  88: 'kaleborecole',
#  89: 'porkintestines',
#  90: 'lettuce',
#  91: 'steamedbread',
#  92: 'reddates',
#  93: 'kiwi',
#  94: 'garlicclove',
#  95: 'crushedgarlic',
#  96: 'garlicbulb',
#  97: 'lentinusedodes',
#  98: 'lentinusedodessliced',
#  99: 'brunoisedicedlentinusedodes',
#  100: 'pleurotusostreatus',
#  101: 'poplarmushroom',
#  102: 'driedmushroom',
#  103: 'whitebeechmushroom',
#  104: 'yamchunks',
#  105: 'whiteyam',
#  106: 'yamsliced',
#  107: 'strawberry',
#  108: 'seacucumber',
#  109: 'shanghaicabbage',
#  110: 'asparagus',
#  111: 'bambooshootschunks',
#  112: 'shreddedbambooshoots',
#  113: 'rice',
#  114: 'meatballs',
#  115: 'beafballs',
#  116: 'shrimpballs',
#  117: 'fishballs',
#  118: 'blueberryjam',
#  119: 'orangesliced',
#  120: 'mango',
#  121: 'noodles',
#  122: 'beefchunks',
#  123: 'beefsliced',
#  124: 'slicedfattybeef',
#  125: 'tofuchunks',
#  126: 'chibabeancurd',
#  127: 'fishbeancurd',
#  128: 'stinkytofu',
#  129: 'shreddeddriedbeancurd',
#  130: 'hobblockspotato',
#  131: 'potatosliced',
#  132: 'shreddedpotato',
#  133: 'mashedpotatoes',
#  134: 'batonnetpotato',
#  135: 'chilioil',
#  136: 'chilisaurce',
#  137: 'chilipowder',
#  138: 'garlicsproutpieces',
#  139: 'brunoisedicedgarlicsprout',
#  140: 'garlicleaves',
#  141: 'pickledredpeppers',
#  142: 'pickledcapsicumannumfasciculatum',
#  143: 'mincedpickledcapsicumannumfasciculatum',
#  144: 'shreddedkelp',
#  145: 'kelp',
#  146: 'bullfrog',
#  147: 'caviar',
#  148: 'lotusrootsliced',
#  149: 'lotusrootchunks',
#  150: 'lotusrootbox',
#  151: 'celtucesclices',
#  152: 'batonnetceltuce',
#  153: 'shreddedceltuce',
#  154: 'sweetpotatochunks',
#  155: 'sausagesliced',
#  156: 'cabbage',
#  157: 'slicedcabbage',
#  158: 'spareribs',
#  159: 'clams',
#  160: 'liliumbrownii',
#  161: 'fermentedvegetables',
#  162: 'double-sidefriedegg',
#  163: 'sliceddouble-sidefriedegg',
#  164: 'radishsliced',
#  165: 'batonnetradish',
#  166: 'hobblocksradish',
#  167: 'shreddedradish',
#  168: 'mashedpickledradish',
#  169: 'pickledradishsliced',
#  170: 'flatbread',
#  171: 'springrolls',
#  172: 'chickenchunks',
#  173: 'brunoisedicedchicken',
#  174: 'tentaclessquid',
#  175: 'squidpieces',
#  176: 'squidrings',
#  177: 'whitegourdchunks',
#  178: 'driedpiecesbeancurd',
#  179: 'yellowpeaches',
#  180: 'pineapple',
#  181: 'eggplant',
#  182: 'eggplantslice',
#  183: 'batonneteggplant',
#  184: 'hobblockseggplant',
#  185: 'eggplantsticks',
#  186: 'watermellon',
#  187: 'gluten',
#  188: 'glutenchunks',
#  189: 'dumplings',
#  190: 'friedbreadstick',
#  191: 'choppedfriedbreadstick',
#  192: 'hotpickledmustard',
#  193: 'sesamesauce',
#  194: 'soya-beansprout',
#  195: 'shreddedbeeftripe',
#  196: 'waterspinach',
#  197: 'shreddedpickledbambooshoots',
#  198: 'barbecuedporksliced',
#  199: 'barbecuedporkchunks',
#  200: 'chickenfeet',
#  201: 'coldsteamedricenoodles',
#  202: 'muttonsliced',
#  203: 'muttonchunks',
#  204: 'crushedsmallloafsteamedbread',
#  205: 'smallloafsteamedbread',
#  206: 'starchsheet',
#  207: 'yuba',
#  208: 'okrasliced',
#  209: 'chestnut',
#  210: 'preservedeggchunks',
#  211: 'crushedpreservedegg',
#  212: 'wholepreservedegg',
#  213: 'laver',
#  214: 'frieddoughtwist',
#  215: 'longan',
#  216: 'stewedpork',
#  217: 'beans',
#  218: 'mincedbeans',
#  219: 'mincedpickledbeans',
#  220: 'sweetfermentedflourpaste',
#  221: 'riversnail',
#  222: 'spinach',
#  223: 'seasedge',
#  224: 'bracken',
#  225: 'coprinuscomatus',
#  226: 'limeleaves',
#  227: 'lemongrass',
#  228: 'lime',
#  229: 'chickenwings',
#  230: 'snowpeas',
#  231: 'pickledvegetable',
#  232: 'saltedegg',
#  233: 'curry',
#  234: 'blackpepperpowder',
#  235: 'friedflour',
#  236: 'wholeblackchicken',
#  237: 'blackchickenchunks',
#  238: 'celerystalksliced',
#  239: 'celerystalk',
#  240: 'celeryleaves',
#  241: 'celery',
#  242: 'brunoisedicedcelery',
#  243: 'bananasliced',
#  244: 'applechunks',
#  245: 'loofah',
#  246: 'fishsliced',
#  247: 'fishchunks',
#  248: 'fish',
#  249: 'zucchinisliced',
#  250: 'boiledchickensliced',
#  251: 'wholeboiledchicken',
#  252: 'tenderloinsliced',
#  253: 'tenderloinchunks',
#  254: 'batonnettenderloin',
#  255: 'whitecongee',
#  256: 'spaghetti',
#  257: 'steak',
#  258: 'cuminpowder',
#  259: 'beeftripes',
#  260: 'pinenuts',
#  261: 'gemelli',
#  262: 'koreanchilisauce',
#  263: 'kidneybean',
#  264: 'zanthoxylumfagara',
#  265: 'ricenoodle',
#  266: 'friedyubaskin',
#  267: 'saladdressing',
#  268: 'soyabean',
#  269: 'fernrootnoodles',
#  270: 'ketchup',
#  271: 'mintleaf',
#  272: 'soysauce',
#  273: 'babychinesecabbage',
#  274: 'water',
#  275: 'lotusseeds',
#  276: 'azukibean',
#  277: 'greensoybean',
#  278: 'parsley',
#  279: 'duckneck',
#  280: 'thickbroad-beansauce',
#  281: 'enokimushroom',
#  282: 'crystalsugar',
#  283: 'cashew',
#  284: 'steamedbun',
#  285: 'soursauce',
#  286: 'porkleg',
#  287: 'bayleaf',
#  288: 'shumai',
#  289: 'craproe',
#  290: 'shrimpeggs',
#  291: 'buttonmushroom',
#  292: 'coconutwater',
#  293: 'glutinousrice',
#  294: 'sweetpotatostarchnoodles',
#  295: 'vermicelli',
#  296: 'fermentedsoyabeans',
#  297: 'ricedumpling',
#  298: 'sweetenedbeanpaste',
#  299: 'sweetdumplings',
#  300: 'ricenoodleroll',
#  301: 'pea',
#  302: 'porkfloss',
#  303: 'scallionpancake',
#  304: 'blackrice',
#  305: 'smallcrispyrice',
#  306: 'coconutcake',
#  307: 'shreddedcoconutstuffing',
#  308: 'mussels',
#  309: 'porklungs',
#  310: 'crispysausage',
#  311: 'codonopsispilosula',
#  312: 'radixastragali',
#  313: 'americangenseng',
#  314: 'cordycepssinensis',
#  315: 'aniseed',
#  316: 'raisin',
#  317: 'sucklingpig',
#  318: 'steamedtwistedroll',
#  319: 'grape',
#  320: 'porkpaste',
#  321: 'cheese',
#  322: 'wonton',
#  323: 'duckhead',
#  324: 'chinesekale',
#  325: 'chickenlegs',
#  326: 'wholechicken',
#  327: 'shreddedchicken',
#  328: 'sweetandsoursauce',
#  329: 'fishhead',
#  330: 'steamedricepowder',
#  331: 'scallop',
#  332: 'macaroni',
#  333: 'ribbonfish',
#  334: 'tea-leaves',
#  335: 'millet',
#  336: 'preservedvegetables',
#  337: 'coixseed',
#  338: 'greenbeans',
#  339: 'whitefungus',
#  340: 'crucian',
#  341: 'vinegar',
#  342: 'pancakes',
#  343: 'crispbread',
#  344: 'mangochunks',
#  345: 'crab',
#  346: 'soya-beanmilk',
#  347: 'fermentedsoybeanpaste',
#  348: 'oystersauce',
#  349: 'spareribschunks',
#  350: 'greensoybeans',
#  351: 'cherry',
#  352: 'shreddedpigears',
#  353: ''}

# %% [markdown]
# ## Model building

# %%
def norm(input, p=2, dim=1, eps=1e-12):
    return input / input.norm(p,dim,keepdim=True).clamp(min=eps).expand_as(input)

# %%
class embedding(nn.Module):
    def __init__(self):
        super(embedding, self).__init__()
        # new feature
        self.feature_emb = nn.Sequential(
            nn.Linear(512, 172), 
            nn.Tanh(),
        )
        # ingredient
        self.ingredient_emb = nn.Sequential(
            nn.Linear(172, 354),
            nn.Softmax(),
        )
         # cutting
        self.cutting_emb = nn.Sequential(
            nn.Linear(172, 14),
            nn.Softmax(),
        )
    
    def forward(self, x):
        x = x.view(-1, 512)
        fea_embedding = self.feature_emb(x)
        fea_embedding = norm(fea_embedding)
        ing_embedding = self.ingredient_emb(fea_embedding)
        cut_embedding = self.cutting_emb(fea_embedding)
        return fea_embedding, ing_embedding, cut_embedding

# %%
class vggfeature(nn.Module):
    def __init__(self):
        super(vggfeature, self).__init__()
        # VGG16 model
        model_vgg = models.vgg16(pretrained = True)
        # pool5 feature maps
#         self.features = model_vgg.features
#         self.features = nn.Sequential(
#             *list(model_vgg.features.children())[:-1] ##
#         )
        self.features = model_vgg.features
    
        for p in self.parameters():
            p.requires_grad = False
        
#         self.pool5=nn.Sequential()
        # new feature
        
        self.feature_emb = nn.Sequential(
            nn.Linear(512, 172), 
            nn.Tanh(),
        )
        # ingredient
        self.ingredient_emb = nn.Sequential(
            nn.Linear(172, 354),
            nn.Softmax(),
        )
         # cutting
        self.cutting_emb = nn.Sequential(
            nn.Linear(172, 14),
            nn.Softmax(),
        )
    
    def forward(self, x):
        x = self.features(x)
        print(x.size)
        x = x.view(-1, 512)
        fea_embedding = self.feature_emb(x)
        fea_embedding = norm(fea_embedding)
        ing_embedding = self.ingredient_emb(fea_embedding)
        cut_embedding = self.cutting_emb(fea_embedding)
        return fea_embedding, ing_embedding, cut_embedding

# %%
def idx_unflatten(tsor, dim):
    b = tsor.cpu().numpy()
    c = []
    for val in b:
        c.append([(int)(val/dim),val%dim])
    c = np.asarray(c)
    new_tensor = torch.from_numpy(c)
    return new_tensor

def pooling(ing_emb, cut_emb):
    
    m2 = ing_emb.size(0)
    ingDim=353
    # get the i-th region of ingredient j
    ing_tmp = ing_emb.view(-1, m2)    
    ing_max, idx = torch.max(ing_tmp, dim=1)
    ing_idx = idx_unflatten(idx, np.sqrt(m2))
    '''
    # select top-k ingredients
    ing, new_idx = torch.topk(ing_max, k)
    indices = torch.LongTensor(new_idx)
    ing_kidx = torch.index_select(ing_idx, 0, indices)
    '''
    # pooling cutting and cooking method of i-th region
    cut_max, cut_idx = torch.max(cut_emb, dim=0)   
    indices = ing_idx.long().cuda()
#     indices = Variable(ing_idx.long().cuda())
#     print(indices.type())
    cut_way = torch.index_select(cut_idx, 0, indices.view(-1))
    cut_proba = torch.index_select(cut_max, 0, indices.view(-1))
    
    # aggregate ingredient and cutting(resp.cooking) tensors
    p_ingre = torch.zeros([ingDim])
    for num, proba in enumerate(ing_max.detach().numpy()):
        p_ingre[num] = proba
    
    p_cut = torch.zeros([cutDim, ingDim])
    
    i = 0
    for idx, proba in zip(cut_way.numpy(), cut_proba.numpy()):
        p_cut[idx][i] = proba
        i += 1
   
    return p_ingre, p_cut

# %%
# original ingredient label is represented as a list
# output is a list of doublet(ing, cut)
def recipe_retrival(ingre_label):
    res = []
    for idx, val in enumerate(ingre_label):
        if val == 1:
            doublet = new_ing_dict[idx]             
            res.append(doublet)
    return res

IngreLabel = open('IngreLabel.txt', 'r').read().split('\n')[:-1]   # list of str
for i in range(len(IngreLabel)):
    IngreLabel[i] = IngreLabel[i].split()                    # list of list, element is str

# Get t_ingre from path
def Get_ingre(path):
    ID = path[11]
    if ID == 'r':    #train
        path = path[15:]
    elif ID == 'a':  #val
        path = path[13:]
    else:            #test
        path = path[14:]
    # path has the same format of that in IngreLabel.txt
    for pil in IngreLabel:
        if pil[0] == path:
            ingre = [int(i) for i in pil[1:]]
            return ingre

# Get t_cut from t_ingre
def Get_cut(t_ingre):
    t_cut = torch.zeros([cutDim, ingDim])
    recipe = recipe_retrival(t_ingre)
    a,b = zip(*recipe)
    c = list(a)   # cut
    t = list(b)   # ingre
    for i in range(len(c)):
        if c[i] != 0:
            t_cut[c[i],t[i]] = 1
    return t_cut

# %%
# Get all recipes
All_recipe = []
for p in IngreLabel:
    ingre = [int(i) for i in p[1:]]
    r = recipe_retrival(ingre)
    All_recipe.append(r)
# R = torch.from_numpy(np.asarray(R))

# %%
# Get dish name for all recipes
Dish_name = []
for p in IngreLabel:
    tmp = p[0]
    tmp = tmp.split('/')
    Dish_name.append(int(tmp[1]))

# %%
#calculate cross entropy between image representation p and target representation t

def loss_function(p_ingre, p_cut, t_ingre, t_cut):
  
    # loss of ingredients
    L1 = nn.BCEWithLogitsLoss(p_ingre, t_ingre)
  
    # ground-truth ingredient set
    a = t_ingre.nonzero().view(-1)
  
    # conditional cutting tensor
    new_p_cut = torch.zeros(p_cut.size())
    for j in a.numpy():
        for i in range(p_cut.size(0)):
            new_p_cut[i][j] = p_cut[i][j]
    # loss of cutting
    L2 = nn.BCEWithLogitsLoss(new_p_cut, t_cut)
  
    L = L1 + L2
    return L

# %%
# recipe R is represented by a list of list(ingredient, cutting, cooking)
# def similarity(Q_ingre, Q_cut, Q_cook, R):
#     simi = 0
#     for triplet in R:
#         ing, cut, cook = triplet[0], triplet[1], triplet[2]
#     simi += Q_ingre[ing] + cc_rate * (Q_cut[cut][ing] + Q_cook[cook][ing])
#     simi /= len(R)
  
#     return simi

def similarity(Q_ingre, Q_cut, R):
    simi = 0
    for doublet in R:
        ing, cut = doublet[0], boublet[1]
    simi += Q_ingre[ing] + cc_rate * Q_cut[cut][ing]
    simi /= len(R)
  
    return simi

def pred_dish(Q_ingre,Q_cut,all_recipe):
    simi = 0
    res = -1
    for idx, recipe in enumerate(all_recipe):
        tmp = similarity(Q_ingre, Q_cut, recipe)
        if tmp > simi:
            simi = tmp
            res = idx
    return(Dish_name[res])

# %% [markdown]
# ## Training

# %% [markdown]
# ### Calculating preconvoluted features

# %%
def preconvfeat(dataset):
    conv_features = []
    labels_list = []
    paths_list = []
    for data in dataset:
        inputs,labels, paths = data
#         print(paths)
        if use_gpu:
            inputs , labels = Variable(inputs.cuda()),Variable(labels.cuda())
        else:
            inputs , labels = Variable(inputs),Variable(labels)
        model = gpu(vggfeature())
        x = model.features(inputs)
        conv_features.extend(x.data.cpu().numpy())
        labels_list.extend(labels.data.cpu().numpy())
        paths_list.extend(list(paths))
    conv_features = np.concatenate([[feat] for feat in conv_features])
    return (conv_features,labels_list,paths_list)

# %%
dataset_valid = torch.utils.data.DataLoader(dsets['val'], batch_size=5, shuffle=True, num_workers=6)
count = 1
for data in dataset_valid:
    if count == 1:
        inputs_try,labels_try, paths_try = data
print(labels_try)
inputs_try , labels_try = gpu(inputs_try),gpu(labels_try)
model = gpu(vggfeature())
x_try = model.features(inputs_try)
print(x_try)
# Out:
# tensor([88])
# tensor([[[[ 0.1169,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  1.6182,  2.1719,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.1212,  1.5126,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 1.7239,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 4.3125,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.2739],
#           [ 0.2786,  3.2627,  2.9672,  ...,  3.4887,  0.9362,  0.0000]],
#
#          [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 1.5685,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 1.4011,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#          ...,
#
#          [[ 2.6956,  0.1355,  2.5897,  ...,  0.3567,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.4386,  ...,  2.5856,  2.6545,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  2.2632,  4.2257],
#           ...,
#           [10.4825,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [10.9159, 15.0018,  2.4257,  ...,  0.0000,  1.4648, 10.8250],
#           [ 1.4252,  7.7980,  3.4808,  ...,  0.0000,  0.0000,  5.5982]],
#
#          [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.2133,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 2.6526,  2.4750,  0.0000,  ...,  0.2740,  0.0000,  0.3035]],
#
#          [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.6190],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  1.9936],
#           [ 0.0000,  0.7140,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           ...,
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]]],
#        device='cuda:0')

# %%
# %%time
conv_feat_train,labels_train, paths_train = preconvfeat(dset_loaders['train'])
# Out:
# CPU times: user 29min 37s, sys: 9min 18s, total: 38min 55s
# Wall time: 38min 55s

# %%
# %%time
conv_feat_val,labels_val, paths_val = preconvfeat(dset_loaders['val'])
# Out:
# CPU times: user 5min, sys: 1min 8s, total: 6min 8s
# Wall time: 6min 9s

# %%
# %%time
# conv_feat_test, labels_test, paths_test = preconvfeat(dset_loaders['test'])

# %%
def save_array(fname, arr):
    c=bcolz.carray(arr, rootdir=fname, mode='w')
    c.flush()
def load_array(fname):
    return bcolz.open(fname)[:]
    
# %mkdir ./cross_model

# %%
save_array(os.path.join('./cross_model','feat_train.bc'),conv_feat_train)
save_array(os.path.join('./cross_model','labels_train.bc'),labels_train)
save_array(os.path.join('./cross_model','paths_train.bc'),paths_train)
save_array(os.path.join('./cross_model','feat_val.bc'),conv_feat_val)
save_array(os.path.join('./cross_model','labels_val.bc'),labels_val)
save_array(os.path.join('./cross_model','paths_val.bc'),paths_val)
# save_array(os.path.join('./cross_model','feat_test.bc'),conv_feat_test)
# save_array(os.path.join('./cross_model','labels_test.bc'),labels_test)

# %% [markdown]
# ### Loading Preconvoluted features

# %%
conv_feat_train = load_array('./cross_model/feat_train.bc')
labels_train = load_array('./cross_model/labels_train.bc')
paths_train = load_array('./cross_model/paths_train.bc')
conv_feat_val = load_array('./cross_model/feat_val.bc')
labels_val = load_array('./cross_model/labels_val.bc')
paths_val = load_array('./cross_model/paths_val.bc')
# conv_feat_test = load_array(data_dir+'/cross_model/conv_feat_test.bc')
# labels_test = load_array(data_dir+'/cross_model/labels_test.bc')

# %%
conv_feat_train.shape
# Out:
# (66071, 512, 7, 7)

# %%
def data_gen(conv_feat,labels,paths,batch_size=64,shuffle=True):
    labels = np.array(labels)
    paths = np.array(paths)
    if shuffle:
        index = np.random.permutation(len(conv_feat))
#         print(index)
#         print(conv_feat)
        conv_feat = conv_feat[index]
        labels = labels[index]
        paths = paths[index]
    for idx in range(0,len(conv_feat),batch_size):
        yield(conv_feat[idx:idx+batch_size],labels[idx:idx+batch_size], paths[idx:idx+batch_size])

# %%
# n_iter=10
batch_size=50
learning_rate=1e-2

optimizer = optim.SGD(embedding().parameters(), learning_rate)

def train_model_emb(model,size_train,size_val,conv_feat_train=None,labels_train=None, paths_train=None, 
                conv_feat_val=None,labels_val=None,paths_val=None,epochs=1,optimizer=None,train=True,shuffle=True):
# def train_model_emb(model,size_train,dataloader=None,epochs=1,optimizer=None,train=True,shuffle=True):
    if train:
        model.train()
    else:
        model.eval()
#     gpu(model)    
    LOSS = []
    ACC = []
    LOSS_V = []
    ACC_V = []
#     train_loader = dataloader['train']
    
    for epoch in range(epochs):
        batches = data_gen(conv_feat=conv_feat_train,labels=labels_train,paths=paths_train,shuffle=shuffle)
#         print(batches)
        total = 0
        running_loss = 0.0
        running_corrects = 0
#         for inputs,classes,paths in train_loader:
        for inputs,classes,paths in batches:
#             print(type(inputs[0]))
#             print(type(classes[0]))
#             print(type(paths[0]))
            inputs,classes = gpu(torch.from_numpy(inputs)),gpu(torch.from_numpy(classes))   
#             inputs = inputs.view(inputs.size(0), -1)
            print(inputs.size())
#             inputs = gpu(inputs).view(inputs.size(0), 3, 224, 224)
    
            fea_embeddings, ing_embeddings, cut_embeddings  = model(inputs)
            loss = []
            preds = []
            for i in range(fea_embeddings.size(0)):
                fea_emb = fea_embeddings[i]
                ing_emb = ing_embeddings[i]
                cut_emb = cut_embeddings[i]
                p_ingre,p_cut = pooling(ing_emb, cut_emb)
                t_ingre = Get_ingre(paths[i])
                t_cut = Get_cut(t_ingre)
                # loss
                l = loss_function(p_ingre, p_cut, t_ingre, t_cut)
                # similarity, retrival
#                 R = recipe_retrival(t_ingre)
#                 simi = similarity(p_ingre, p_cut, R)
                pred = pred_dish(p_ingre,p_cut,All_recipe)
                loss.append(l)
                preds.append(pred)
            loss = torch.FloatTensor(loss)
            preds = torch.FloatTensor(preds)
            
            if optimizer is None:
                raise ValueError('Pass optimizer for train mode')
            optimizer = optimizer
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
#             if train:
#                 if optimizer is None:
#                     raise ValueError('Pass optimizer for train mode')
#                 optimizer = optimizer
#                 optimizer.zero_grad()
#                 loss.backward()
#                 optimizer.step()            
            
            # statistics
            running_loss += loss.data.item()
            running_corrects += torch.sum(preds == classes.data)
        epoch_loss = running_loss / size_train
        epoch_acc = running_corrects.data.item() / size_train
        LOSS.append(epoch_loss)
        ACC.append(epoch_acc)
        print('Epoch: {} Training Loss: {:.4f} Training Acc: {:.4f}'.format(
                     epoch+1, epoch_loss, epoch_acc))
        
#         batches = data_gen(conv_feat=conv_feat_val,labels=labels_val,paths=paths_val,shuffle=shuffle)
#         total = 0
#         running_loss = 0.0
#         running_corrects = 0
#         for inputs,classes,paths in batches:
#             inputs,classes = gpu(torch.from_numpy(inputs)),gpu(torch.from_numpy(classes))       
                            
#             inputs = inputs.view(inputs.size(0), -1)
            
#             fea_embeddings, ing_embeddings, cut_embeddings  = model(inputs)
#             loss = []
#             preds = []
#             for i in range(fea_embeddings.size(0)):
#                 fea_emb = fea_embeddings[i]
#                 ing_emb = ing_embeddings[i]
#                 cut_emb = cut_embeddings[i]
#                 p_ingre,p_cut = pooling(ing_emb, cut_emb)
#                 t_ingre = Get_ingre(paths[i])
#                 t_cut = Get_cut(t_ingre)
#                 # loss
#                 l = loss_function(p_ingre, p_cut, t_ingre, t_cut)
#                 # similarity, retrival           
#                 pred = pred_dish(p_ingre,p_cut,All_recipe)
#                 loss.append(l)
#                 preds.append(pred)
#             loss = torch.FloatTensor(loss)
#             preds = torch.FloatTensor(preds)
#             # statistics
#             running_loss += loss.data.item()
#             running_corrects += torch.sum(preds == classes.data)
#         epoch_loss = running_loss / size_val
#         epoch_acc = running_corrects.data.item() / size_val
#         LOSS_V.append(epoch_loss)
#         ACC_V.append(epoch_acc)
#         print('Epoch: {} Validation Loss: {:.4f} Validation Acc: {:.4f}'.format(
#                      epoch+1, epoch_loss, epoch_acc))
        
#     return 
#     return LOSS, ACC, LOSS_V, ACC_V
    return LOSS, ACC

# %%
LOSS, ACC = (train_model_emb(model=gpu(embedding()),
            size_train=dset_sizes['train'],size_val=dset_sizes['val'],
            conv_feat_train=conv_feat_train,labels_train=labels_train,
            paths_train=paths_train,
            conv_feat_val=conv_feat_val,labels_val=labels_val,
            paths_val=paths_val,
            epochs=50,optimizer=optimizer,train=True,shuffle=True))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-48-cf5b8f964686> in <module>
# ----> 1 LOSS, ACC = (train_model_emb(model=gpu(embedding()),
#       2             size_train=dset_sizes['train'],size_val=dset_sizes['val'],
#       3             conv_feat_train=conv_feat_train,labels_train=labels_train,
#       4             paths_train=paths_train,
#       5             conv_feat_val=conv_feat_val,labels_val=labels_val,
#
# <ipython-input-2-50ef36d1125d> in gpu(x, use_gpu)
#       3 def gpu(x,use_gpu=use_gpu):
#       4     if use_gpu:
# ----> 5         return x.cuda()
#       6     else:
#       7         return x
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in cuda(self, device)
#     258             Module: self
#     259         """
# --> 260         return self._apply(lambda t: t.cuda(device))
#     261
#     262     def cpu(self):
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     185     def _apply(self, fn):
#     186         for module in self.children():
# --> 187             module._apply(fn)
#     188
#     189         for param in self._parameters.values():
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     185     def _apply(self, fn):
#     186         for module in self.children():
# --> 187             module._apply(fn)
#     188
#     189         for param in self._parameters.values():
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     191                 # Tensors stored in modules are graph leaves, and we don't
#     192                 # want to create copy nodes, so we have to unpack the data.
# --> 193                 param.data = fn(param.data)
#     194                 if param._grad is not None:
#     195                     param._grad.data = fn(param._grad.data)
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in <lambda>(t)
#     258             Module: self
#     259         """
# --> 260         return self._apply(lambda t: t.cuda(device))
#     261
#     262     def cpu(self):
#
# RuntimeError: CUDA error: device-side assert triggered

# %%
# n_iter=10
batch_size=50
learning_rate=1e-2

optimizer = optim.SGD(vggfeature().parameters(), learning_rate)

# def train_model(model,size_train,size_val,conv_feat_train=None,labels_train=None, paths_train=None, 
#                 conv_feat_val=None,labels_val=None,paths_val=None,epochs=1,optimizer=None,train=True,shuffle=True):
def train_model(model,size_train,dataloader=None,epochs=1,optimizer=None,train=True,shuffle=True):
    if train:
        model.train()
    else:
        model.eval()
#     gpu(model)    
    LOSS = []
    ACC = []
    LOSS_V = []
    ACC_V = []
    train_loader = dataloader['train']
    
    for epoch in range(epochs):
#         batches = data_gen(conv_feat=conv_feat_train,labels=labels_train,paths=paths_train,shuffle=shuffle)
#         print(batches)
        total = 0
        running_loss = 0.0
        running_corrects = 0
        for inputs,classes,paths in train_loader:
#         for inputs,classes,paths in batches:
#             print(type(inputs[0]))
#             print(type(classes[0]))
#             print(type(paths[0]))
#             inputs,classes = gpu(torch.from_numpy(inputs)),gpu(torch.from_numpy(classes))        
#             inputs = inputs.view(inputs.size(0), -1)
#             print(inputs.size())
            inputs = gpu(inputs).view(inputs.size(0), 3, 224, 224)
    
            fea_embeddings, ing_embeddings, cut_embeddings  = model(inputs)
            loss = []
            preds = []
            for i in range(fea_embeddings.size(0)):
                fea_emb = fea_embeddings[i]
                ing_emb = ing_embeddings[i]
                cut_emb = cut_embeddings[i]
                p_ingre,p_cut = pooling(ing_emb, cut_emb)
                t_ingre = Get_ingre(paths[i])
                t_cut = Get_cut(t_ingre)
                # loss
                l = loss_function(p_ingre, p_cut, t_ingre, t_cut)
                # similarity, retrival
#                 R = recipe_retrival(t_ingre)
#                 simi = similarity(p_ingre, p_cut, R)
                pred = pred_dish(p_ingre,p_cut,All_recipe)
                loss.append(l)
                preds.append(pred)
            loss = torch.FloatTensor(loss)
            preds = torch.FloatTensor(preds)
            
            if optimizer is None:
                raise ValueError('Pass optimizer for train mode')
            optimizer = optimizer
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
#             if train:
#                 if optimizer is None:
#                     raise ValueError('Pass optimizer for train mode')
#                 optimizer = optimizer
#                 optimizer.zero_grad()
#                 loss.backward()
#                 optimizer.step()            
            
            # statistics
            running_loss += loss.data.item()
            running_corrects += torch.sum(preds == classes.data)
        epoch_loss = running_loss / size_train
        epoch_acc = running_corrects.data.item() / size_train
        LOSS.append(epoch_loss)
        ACC.append(epoch_acc)
        print('Epoch: {} Training Loss: {:.4f} Training Acc: {:.4f}'.format(
                     epoch+1, epoch_loss, epoch_acc))
        
#         batches = data_gen(conv_feat=conv_feat_val,labels=labels_val,paths=paths_val,shuffle=shuffle)
#         total = 0
#         running_loss = 0.0
#         running_corrects = 0
#         for inputs,classes,paths in batches:
#             inputs,classes = gpu(torch.from_numpy(inputs)),gpu(torch.from_numpy(classes))       
                            
#             inputs = inputs.view(inputs.size(0), -1)
            
#             fea_embeddings, ing_embeddings, cut_embeddings  = model(inputs)
#             loss = []
#             preds = []
#             for i in range(fea_embeddings.size(0)):
#                 fea_emb = fea_embeddings[i]
#                 ing_emb = ing_embeddings[i]
#                 cut_emb = cut_embeddings[i]
#                 p_ingre,p_cut = pooling(ing_emb, cut_emb)
#                 t_ingre = Get_ingre(paths[i])
#                 t_cut = Get_cut(t_ingre)
#                 # loss
#                 l = loss_function(p_ingre, p_cut, t_ingre, t_cut)
#                 # similarity, retrival           
#                 pred = pred_dish(p_ingre,p_cut,All_recipe)
#                 loss.append(l)
#                 preds.append(pred)
#             loss = torch.FloatTensor(loss)
#             preds = torch.FloatTensor(preds)
#             # statistics
#             running_loss += loss.data.item()
#             running_corrects += torch.sum(preds == classes.data)
#         epoch_loss = running_loss / size_val
#         epoch_acc = running_corrects.data.item() / size_val
#         LOSS_V.append(epoch_loss)
#         ACC_V.append(epoch_acc)
#         print('Epoch: {} Validation Loss: {:.4f} Validation Acc: {:.4f}'.format(
#                      epoch+1, epoch_loss, epoch_acc))
        
#     return 
#     return LOSS, ACC, LOSS_V, ACC_V
    return LOSS, ACC
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-f180cf65d139> in <module>
#       3 learning_rate=1e-2
#       4
# ----> 5 optimizer = optim.SGD(vggfeature().parameters(), learning_rate)
#       6
#       7 # def train_model(model,size_train,size_val,conv_feat_train=None,labels_train=None, paths_train=None,
#
# NameError: name 'vggfeature' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-cbc37183d6b7> in <module>
# ----> 1 gpu(vggfeature())
#
# <ipython-input-3-50ef36d1125d> in gpu(x, use_gpu)
#       3 def gpu(x,use_gpu=use_gpu):
#       4     if use_gpu:
# ----> 5         return x.cuda()
#       6     else:
#       7         return x
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in cuda(self, device)
#     258             Module: self
#     259         """
# --> 260         return self._apply(lambda t: t.cuda(device))
#     261
#     262     def cpu(self):
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     185     def _apply(self, fn):
#     186         for module in self.children():
# --> 187             module._apply(fn)
#     188
#     189         for param in self._parameters.values():
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     185     def _apply(self, fn):
#     186         for module in self.children():
# --> 187             module._apply(fn)
#     188
#     189         for param in self._parameters.values():
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     191                 # Tensors stored in modules are graph leaves, and we don't
#     192                 # want to create copy nodes, so we have to unpack the data.
# --> 193                 param.data = fn(param.data)
#     194                 if param._grad is not None:
#     195                     param._grad.data = fn(param._grad.data)
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in <lambda>(t)
#     258             Module: self
#     259         """
# --> 260         return self._apply(lambda t: t.cuda(device))
#     261
#     262     def cpu(self):
#
# RuntimeError: CUDA error: device-side assert triggered

# %%
LOSS, ACC = train_model(model=gpu(vggfeature()),size_train=dset_sizes['train'],
                        dataloader=dset_loaders,epochs=50,optimizer=optimizer,train=True,shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-1efa0b829f10> in <module>
#       1
# ----> 2 LOSS, ACC = train_model(model=gpu(vggfeature()),size_train=dset_sizes['train'],
#       3                         dataloader=dset_loaders,epochs=50,optimizer=optimizer,train=True,shuffle=True)
#
# <ipython-input-3-50ef36d1125d> in gpu(x, use_gpu)
#       3 def gpu(x,use_gpu=use_gpu):
#       4     if use_gpu:
# ----> 5         return x.cuda()
#       6     else:
#       7         return x
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in cuda(self, device)
#     258             Module: self
#     259         """
# --> 260         return self._apply(lambda t: t.cuda(device))
#     261
#     262     def cpu(self):
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     185     def _apply(self, fn):
#     186         for module in self.children():
# --> 187             module._apply(fn)
#     188
#     189         for param in self._parameters.values():
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     185     def _apply(self, fn):
#     186         for module in self.children():
# --> 187             module._apply(fn)
#     188
#     189         for param in self._parameters.values():
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     191                 # Tensors stored in modules are graph leaves, and we don't
#     192                 # want to create copy nodes, so we have to unpack the data.
# --> 193                 param.data = fn(param.data)
#     194                 if param._grad is not None:
#     195                     param._grad.data = fn(param._grad.data)
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in <lambda>(t)
#     258             Module: self
#     259         """
# --> 260         return self._apply(lambda t: t.cuda(device))
#     261
#     262     def cpu(self):
#
# RuntimeError: CUDA error: device-side assert triggered

# %%
# %%time
LOSS, ACC, LOSS_V, ACC_V = (train_model(model=gpu(vggfeature()),
            size_train=dset_sizes['train'],size_val=dset_sizes['val'],
            conv_feat_train=conv_feat_train,labels_train=labels_train,
            paths_train=paths_train,
            conv_feat_val=conv_feat_val,labels_val=labels_val,
            paths_val=paths_val,
            epochs=50,optimizer=optimizer,train=True,shuffle=True))
# Out:
# torch.Size([64, 512, 7, 7])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-100-6b37265942e9> in train_model(model, size_train, size_val, conv_feat_train, labels_train, paths_train, conv_feat_val, labels_val, paths_val, epochs, optimizer, train, shuffle)
#      29 #             inputs = inputs.view(inputs.size(0), -1)
#      30             print(inputs.size())
# ---> 31             fea_embeddings, ing_embeddings, cut_embeddings  = model(inputs)
#      32             loss = []
#      33             preds = []
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-65-f71c6aa3b85f> in forward(self, x)
#      32
#      33     def forward(self, x):
# ---> 34         x = self.features(x)
#      35         print(x.size)
#      36         x = x.view(x.size(0), -1)
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/ENTER/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# RuntimeError: Given groups=1, weight of size [64, 3, 3, 3], expected input[64, 512, 7, 7] to have 3 channels, but got 512 channels instead

# %%
model = vggfeature()
print(model)
# Out:
# vggfeature(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (feature_emb): Sequential(
#     (0): Linear(in_features=512, out_features=172, bias=True)
#     (1): Tanh()
#   )
#   (ingredient_emb): Sequential(
#     (0): Linear(in_features=172, out_features=354, bias=True)
#     (1): Softmax()
#   )
#   (cutting_emb): Sequential(
#     (0): Linear(in_features=172, out_features=14, bias=True)
#     (1): Softmax()
#   )
# )
